# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-a8b645fc-f6b8-465c-b320-5209db32119a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a8b645fc-f6b8-465c-b320-5209db32119a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving upload.csv to upload.csv
# ...

# %%
import pandas as pd

data = pd.read_csv("upload.csv")

# %%
data
# Out:
#                            ID     Name
# 0    615ef4a5fc13ae6ec800044c      Rea
# 1    615ef4a5fc13ae6ec800044d    Aleda
# 2    615ef4a5fc13ae6ec800044e  Roxanna
# 3    615ef4a5fc13ae6ec800044f     Ibby
# 4    615ef4a5fc13ae6ec8000450  Juliann
# ..                        ...      ...
# 995  615ef4a6fc13ae6ec800082f   Meriel
# 996  615ef4a6fc13ae6ec8000830     Fran
# 997  615ef4a6fc13ae6ec8000831   Yvette
# 998  615ef4a6fc13ae6ec8000832     Kala
# 999  615ef4a6fc13ae6ec8000833    Maria
#
# [1000 rows x 2 columns]

# %%
files.upload()
# Out:
#      <input type="file" id="files-96c8941b-5fff-41d8-8009-951b1a782d78" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-96c8941b-5fff-41d8-8009-951b1a782d78">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving upload.jpg to upload.jpg
# ...

# %%
from IPython.display import display
from PIL import Image

path_to_image = "upload.jpg"

display(Image.open(path_to_image))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=728x423 at 0x7FDD142E29D0>
